# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the data

# %%
df = pd.read_csv('Cardiotocographic.csv')

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# # EDA

# %%
# For LB column

# %%
df['LB'].isnull().sum()
# Out:
# 21

# %%
df['LB'].fillna(method='bfill', inplace=True) # Using bfill method to fill null values

# %%
# doing this for all values in dataset

# %%
df.fillna(method='bfill', inplace=True)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# Detecting Outliers for each columns

# %%
# For LB column

# %%
plt.hist(df['LB'])
plt.show()

# %%
df['LB'].skew()
# Out:
# 0.32463796135648115

# %%
# Plotting boxplot

# %%
box1 = plt.boxplot(df['LB'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box1['fliers']]

# %%
df[df['LB'].isin(outlier[0])]
# Out:
#               LB        AC        FM        UC        DL        DS        DP  \
# 134    52.000000  0.001590  0.000000  0.029851  0.000000  0.000000  0.000003
# 411   214.000000  0.000000  0.000000  0.001595  0.001595  0.000000  0.000000
# 610   214.000000  0.002469  0.002469  0.002469  0.000000  0.000004  0.000000
# 612   214.000000  0.005181  0.012953  0.002591  0.000000  0.000000  0.000000
# 785    52.000000  0.000834  0.013344  0.000000  0.000000  0.000000  0.000000
# 1027   51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.000000
# 1103  214.000000  0.006972  0.000000  0.002960  0.000000  0.000000  0.000000
# 1406  214.000000  0.005068  0.000000  0.001689  0.000000  0.000000  0.000000
# 1504  214.000000  0.006189  0.000000  0.006189  0.000000  0.000000  0.000000
# 1834   52.188547  0.000000  0.001043  0.003128  0.007299  0.000000  0.000000
#
#            ASTV      MSTV  ALTV  MLTV      Width  Tendency     NSP
# ...

# %%
# Winsorizing outlier of LB column

# %%
from scipy.stats.mstats import winsorize

# %%
winsorized_data = winsorize(df['LB'], limits=[0.05, 0.05])

# %%
df['LB'] = winsorized_data

# %%
plt.boxplot(df['LB'])
plt.show()

# %%
# for AC column

# %%
plt.hist(df['AC'])
plt.show()

# %%
df['AC'].skew()
# Out:
# 2.0032733272594183

# %%
# plotting boxplot

# %%
box2 = plt.boxplot(df['AC'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box2['fliers']]

# %%
df[df['AC'].isin(outlier[0])]
# Out:
#          LB        AC        FM        UC        DL        DS        DP  \
# 8     122.0  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 23    128.0 -0.019284  0.000000  0.000000  0.000000  0.000000  0.000000
# 83    145.0  0.014706  0.008403  0.002101  0.000000  0.000000  0.000000
# 85    145.0  0.014230  0.025873  0.001294  0.000000  0.000000  0.000000
# 116   123.0  0.038567  0.000000  0.006993  0.002331  0.000000  0.000000
# 157   123.0 -0.019284  0.000000  0.006400  0.000000  0.000000  0.000000
# 181   138.0  0.017241  0.000000  0.005305  0.000000  0.000000  0.000000
# 496   130.0  0.014178  0.091743  0.000938  0.000000  0.000000  0.000000
# 497   130.0  0.015552  0.083981  0.001555 -0.000026  0.000000  0.000000
# 498   130.0  0.015258  0.115023  0.000000  0.000000  0.000000  0.000000
# 500   131.0  0.014178  0.015013  0.000834  0.000000  0.000000  0.000000
# 501   131.0  0.014726  0.017403  0.001339  0.000000  0.000000  0.000000
# ...

# %%
# Winsorizing outlier of AC column

# %%
winsorized_data = winsorize(df['AC'], limits=[0.05, 0.05])

# %%
df['AC'] = winsorized_data

# %%
plt.boxplot(df['AC'])
plt.show()

# %%
# For FM column

# %%
plt.hist(df['FM'])
plt.show()

# %%
# Here Distribution of data is not there so we drop that column for further use

# %%
df.drop(columns='FM', inplace=True)

# %%
df
# Out:
#               LB        AC        UC        DL   DS   DP  ASTV  MSTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 1     132.000000  0.006380  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     133.000000  0.003322  0.008306  0.003322  0.0  0.0  16.0   2.1
# 3     134.000000  0.002561  0.007742  0.002561  0.0  0.0  16.0   2.4
# 4     131.948232  0.006515  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...          ...       ...       ...       ...  ...  ...   ...   ...
# 2121  140.000000  0.000000  0.007426  0.000000  0.0  0.0  79.0   0.2
# 2122  140.000000  0.000775  0.006979  0.000000  0.0  0.0  78.0   0.4
# 2123  140.000000  0.000980  0.006863  0.000000  0.0  0.0  79.0   0.4
# 2124  140.000000  0.000679  0.006110  0.000000  0.0  0.0  78.0   0.4
# 2125  142.000000  0.001616  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 0     43.000000   2.4   64.0  0.999926  2.000000
# ...

# %%
# For DL column

# %%
plt.hist(df['DL'])
plt.show()

# %%
df['DL'].skew()
# Out:
# 2.0103895349327043

# %%
# Here AC and DL are Correlated since the hist plot is same So we drop DL column

# %%
df.drop(columns='DL', inplace=True)

# %%
df
# Out:
#               LB        AC        UC   DS   DP  ASTV  MSTV       ALTV  MLTV  \
# 0     120.000000  0.000000  0.000000  0.0  0.0  73.0   0.5  43.000000   2.4
# 1     132.000000  0.006380  0.006380  0.0  0.0  17.0   2.1   0.000000  10.4
# 2     133.000000  0.003322  0.008306  0.0  0.0  16.0   2.1   0.000000  13.4
# 3     134.000000  0.002561  0.007742  0.0  0.0  16.0   2.4   0.000000  23.0
# 4     131.948232  0.006515  0.008143  0.0  0.0  16.0   2.4   0.000000  19.9
# ...          ...       ...       ...  ...  ...   ...   ...        ...   ...
# 2121  140.000000  0.000000  0.007426  0.0  0.0  79.0   0.2  25.000000   7.2
# 2122  140.000000  0.000775  0.006979  0.0  0.0  78.0   0.4  22.000000   7.1
# 2123  140.000000  0.000980  0.006863  0.0  0.0  79.0   0.4  20.000000   6.1
# 2124  140.000000  0.000679  0.006110  0.0  0.0  78.0   0.4  27.000000   7.0
# 2125  142.000000  0.001616  0.008078  0.0  0.0  74.0   0.4  35.857183   5.0
#
#       Width  Tendency       NSP
# ...

# %%
# For UC column

# %%
plt.hist(df['UC'])
plt.show()

# %%
df['UC'].skew()
# Out:
# 0.9742394510625922

# %%
# plotting boxplot

# %%
box3 = plt.boxplot(df['UC'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box3['fliers']]

# %%
df[df['UC'].isin(outlier[0])]
# Out:
#               LB        AC        UC   DS        DP  ASTV  MSTV  ALTV  MLTV  \
# 134   119.000000  0.001590  0.029851  0.0  0.000003  58.0   0.5   0.0   7.9
# 543   140.000000  0.000029  0.029851  0.0  0.000000  53.0   0.7   0.0  14.8
# 793   146.000000  0.000388 -0.014925  0.0  0.000000  52.0   0.8  32.0   8.6
# 917   121.851326  0.000000  0.029851  0.0  0.001706  33.0   1.1   8.0   7.2
# 1164  131.000000  0.010661  0.014925  0.0  0.000000  26.0   1.5   0.0   3.0
# 1396  142.000000  0.000872 -0.014925  0.0  0.000000  49.0   0.9  28.0   5.8
# 1469  148.000000  0.003633 -0.014925  0.0  0.000000  36.0   0.8   8.0   9.4
# 1593  134.000000  0.000000  0.029936  0.0  0.000000  20.0   2.1   0.0   8.2
# 1671  119.000000  0.003799  0.029851  0.0 -0.000017  65.0   1.1   0.0   9.3
# 1717  131.000000  0.009857  0.030002  0.0  0.000000  54.0   1.4   0.0   3.3
# 1868  138.000000  0.007143 -0.014925  0.0  0.000000  49.0   1.6   0.0   6.0
# ...

# %%
# Winsoring the outlier

# %%
winsorized_data = winsorize(df['UC'], limits=[0.05, 0.05])

# %%
df['UC'] = winsorized_data

# %%
plt.boxplot(df['UC'])
plt.show()

# %%
# For DL data

# %%
plt.hist(df['DS'])
plt.show()

# %%
# Here Distribution of data is not there so we drop that column for further use

# %%
df.drop(columns='DS', inplace=True)

# %%
df
# Out:
#               LB        AC        UC   DP  ASTV  MSTV       ALTV  MLTV  Width  \
# 0     120.000000  0.000000  0.000000  0.0  73.0   0.5  43.000000   2.4   64.0
# 1     132.000000  0.006380  0.006380  0.0  17.0   2.1   0.000000  10.4  130.0
# 2     133.000000  0.003322  0.008306  0.0  16.0   2.1   0.000000  13.4  130.0
# 3     134.000000  0.002561  0.007742  0.0  16.0   2.4   0.000000  23.0  117.0
# 4     131.948232  0.006515  0.008143  0.0  16.0   2.4   0.000000  19.9  117.0
# ...          ...       ...       ...  ...   ...   ...        ...   ...    ...
# 2121  140.000000  0.000000  0.007426  0.0  79.0   0.2  25.000000   7.2   40.0
# 2122  140.000000  0.000775  0.006979  0.0  78.0   0.4  22.000000   7.1   66.0
# 2123  140.000000  0.000980  0.006863  0.0  79.0   0.4  20.000000   6.1   67.0
# 2124  140.000000  0.000679  0.006110  0.0  78.0   0.4  27.000000   7.0   66.0
# 2125  142.000000  0.001616  0.008078  0.0  74.0   0.4  35.857183   5.0   42.0
#
#       Tendency       NSP
# ...

# %%
# For DP column

# %%
plt.hist(df['DP'])
plt.show()

# %%
df['DP'].std()
# Out:
# 0.0008387184647221813

# %%
# Here std deviation of column is low so we drop that column

# %%
df.drop(columns='DP', inplace=True)

# %%
df
# Out:
#               LB        AC        UC  ASTV  MSTV       ALTV  MLTV  Width  \
# 0     120.000000  0.000000  0.000000  73.0   0.5  43.000000   2.4   64.0
# 1     132.000000  0.006380  0.006380  17.0   2.1   0.000000  10.4  130.0
# 2     133.000000  0.003322  0.008306  16.0   2.1   0.000000  13.4  130.0
# 3     134.000000  0.002561  0.007742  16.0   2.4   0.000000  23.0  117.0
# 4     131.948232  0.006515  0.008143  16.0   2.4   0.000000  19.9  117.0
# ...          ...       ...       ...   ...   ...        ...   ...    ...
# 2121  140.000000  0.000000  0.007426  79.0   0.2  25.000000   7.2   40.0
# 2122  140.000000  0.000775  0.006979  78.0   0.4  22.000000   7.1   66.0
# 2123  140.000000  0.000980  0.006863  79.0   0.4  20.000000   6.1   67.0
# 2124  140.000000  0.000679  0.006110  78.0   0.4  27.000000   7.0   66.0
# 2125  142.000000  0.001616  0.008078  74.0   0.4  35.857183   5.0   42.0
#
#       Tendency       NSP
# 0     0.999926  2.000000
# 1     0.000000  1.000000
# ...

# %%
# For ASTV column

# %%
plt.hist(df['ASTV'])
plt.show()

# %%
df['ASTV'].skew()
# Out:
# 0.055871676734938334

# %%
# plotting boxplot

# %%
box4 = plt.boxplot(df['ASTV'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box4['fliers']]
df[df['ASTV'].isin(outlier[0])]
# Out:
#          LB        AC        UC   ASTV  MSTV  ALTV       MLTV       Width  \
# 131   149.0  0.000000  0.000000  -63.0   0.6  31.0   8.600000   92.000000
# 232   123.0  0.003650  0.000000  162.0   0.7   0.0   8.600000   71.000000
# 345   139.0  0.000000  0.000000  162.0   0.2  59.0   4.200000   11.000000
# 504   128.0  0.008253  0.004127  -63.0   1.1   0.0  12.700000  123.000000
# 1014  139.0  0.006312  0.004509  162.0   0.8   0.0   7.600000   33.913652
# 1027  119.0  0.009485  0.005420  -63.0   2.5   0.0   3.900000   98.000000
# 1195  138.0  0.011189  0.005342  -63.0   1.2   0.0   4.100000   48.000000
# 1578  132.0  0.000000  0.002994  -63.0   1.1   0.0  13.700000   52.000000
# 1941  133.0  0.000000  0.006233  162.0   2.1   0.0   1.527002   98.000000
# 2008  125.0  0.001196  0.008373  162.0   1.1   0.0   4.100000  100.000000
#
#       Tendency      NSP
# 131        1.0  1.00000
# 232        1.0  0.98342
# 345        0.0  2.00000
# 504        0.0  1.00000
# 1014      -1.0  1.00000
# ...

# %%
# Winsoring the outlier

# %%
winsorized_data = winsorize(df['ASTV'], limits=[0.05, 0.05])

# %%
df['ASTV'] = winsorized_data

# %%
plt.boxplot(df['ASTV'])
plt.show()

# %%
# For MSTV column

# %%
plt.hist(df['MSTV'])
plt.show()

# %%
df['MSTV'].skew()
# Out:
# 4.14251826362969

# %%
# plotting boxplot

# %%
box5 = plt.boxplot(df['MSTV'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box5['fliers']]
df[df['MSTV'].isin(outlier[0])]
# Out:
#          LB        AC        UC       ASTV  MSTV      ALTV       MLTV  Width  \
# 5     134.0  0.001116  0.009278  26.000000   5.9  0.000000   0.000000  150.0
# 6     134.0  0.001403  0.009278  29.000000   6.3  0.000000   0.000000  150.0
# 28    132.0  0.000000  0.000834  29.000000   4.4  0.000000  10.500000  141.0
# 29    132.0  0.000000  0.000000  26.000000   6.0  0.000000   5.000000  143.0
# 30    132.0  0.000000  0.001702  26.487809   4.5  0.000000  12.500000  149.0
# ...     ...       ...       ...        ...   ...       ...        ...    ...
# 2024  129.0  0.000000  0.005008  58.000000   3.9  0.000000   0.000000  158.0
# 2034  129.0  0.000000  0.006438  67.000000   3.3 -0.133584  -0.172075  129.0
# 2048  128.0  0.000000  0.008032  63.000000   4.2  0.000000   0.000000   90.0
# 2049  125.0  0.004768  0.007151  66.000000   4.1  5.000000   0.300000   23.0
# 2051  127.0  0.002587  0.005283  66.000000   4.2  5.000000   0.300000   23.0
#
#       Tendency       NSP
# ...

# %%
# Winsoring the outlier
winsorized_data = winsorize(df['MSTV'], limits=[0.05, 0.05])

# %%
df['MSTV'] = winsorized_data
plt.boxplot(df['MSTV'])
plt.show()

# %%
# For ALTV column

# %%
plt.hist(df['ALTV'])
plt.show()

# %%
df['ALTV'].skew()
# Out:
# 2.9811987992454214

# %%
# doing cube root transformation to reduce skewness

# %%
df['ALTV'] = np.cbrt(df['ALTV'])

# %%
plt.hist(df['ALTV'])
plt.show()

# %%
# plotting boxplot
box6 = plt.boxplot(df['ALTV'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box6['fliers']]
df[df['ALTV'].isin(outlier[0])]
# Out:
#               LB        AC        UC  ASTV  MSTV      ALTV  MLTV  Width  \
# 128   149.000000  0.000000  0.002937  65.0   0.4  5.667051   6.8   15.0
# 259   127.000000  0.004329  0.009278  21.0   3.0  5.667051  10.1   98.0
# 802   146.507943  0.000000  0.006369  65.0   0.4 -4.497941   7.4   30.0
# 921   122.000000  0.000000  0.006649  31.0   1.0  5.667051   9.5   32.0
# 1068  133.000000  0.009579  0.005747  33.0   1.2 -4.497941   4.4   82.0
# 1105  122.000000  0.002799  0.001866  21.0   2.0 -4.497941  17.7   46.0
# 1308  138.000000  0.003394  0.007919  28.0   1.3  5.667051   3.5   90.0
# 1501  132.000000  0.007853  0.009278  29.0   1.6  5.662949   7.4   92.0
# 1623  126.000000  0.011189  0.006707  53.0   2.5  5.667051   0.3   85.0
# 1770  120.000000  0.000000  0.001148  64.0   1.1  5.667051   0.0   80.0
#
#       Tendency       NSP
# 128        1.0  2.000000
# 259        1.0  1.000000
# 802        0.0  1.998602
# 921        1.0  1.000000
# 1068       1.0  1.000000
# ...

# %%
# Winsoring the outlier
winsorized_data = winsorize(df['ALTV'], limits=[0.05, 0.05])

# %%
df['ALTV'] = winsorized_data

# %%
plt.boxplot(df['ALTV'])
plt.show()

# %%
# For MLTV column

# %%
plt.hist(df['MLTV'])
plt.show()

# %%
df['MLTV'].skew()
# Out:
# 3.5341082687686005

# %%
# plotting boxplot
box7 = plt.boxplot(df['MLTV'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box7['fliers']]
df[df['MLTV'].isin(outlier[0])]
# Out:
#          LB        AC        UC  ASTV  MSTV      ALTV   MLTV  Width  Tendency  \
# 3     134.0  0.002561  0.007742  21.0   2.4  0.000000   23.0  117.0       1.0
# 10    149.0  0.000000  0.000834  64.0   1.9  2.080084   27.6  130.0       1.0
# 11    149.0  0.000000  0.001014  64.0   2.0  2.000000   29.5  130.0       1.0
# 33    120.0  0.007506  0.000800  28.0   3.0  0.000000   21.7  126.0       0.0
# 35    120.0  0.006061  0.007273  27.0   3.0  0.000000   24.2  144.0       0.0
# ...     ...       ...       ...   ...   ...       ...    ...    ...       ...
# 1750  134.0  0.004800  0.001600  62.0   1.5  0.000000  101.4  113.0      -1.0
# 1800  143.0  0.000000  0.003717  66.0   0.4  1.709976  -50.7   24.0       0.0
# 1818  139.0  0.011139  0.007049  53.0   1.5  0.000000   21.0  107.0       0.0
# 1882  139.0  0.001835  0.006422  58.0   0.7  1.259921  101.4   51.0       1.0
# 2033  129.0  0.000000  0.006734  67.0   3.0  0.000000  -50.7   80.0       0.0
#
#       NSP
# 3     1.0
# ...

# %%
# Winsoring the outlier
winsorized_data = winsorize(df['MLTV'], limits=[0.05, 0.05])

# %%
df['MLTV'] = winsorized_data

# %%
plt.boxplot(df['MLTV'])
plt.show()

# %%
# For Width column

# %%
plt.hist(df['Width'])
plt.show()

# %%
df['Width'].skew()
# Out:
# 0.4921245269466651

# %%
# plotting boxplot
box8 = plt.boxplot(df['Width'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box8['fliers']]
df[df['Width'].isin(outlier[0])]
# Out:
#               LB        AC        UC  ASTV  MSTV      ALTV  MLTV  Width  \
# 54    147.816574  0.000000  0.000000  70.0   0.3  3.870877   5.1 -174.0
# 64    141.000000  0.001282  0.005128  25.0   1.5  0.000000  13.4 -174.0
# 120   123.000000  0.000000  0.005004  47.0   1.1  3.114086   7.4  357.0
# 389   129.000000  0.008264  0.002066  37.0   1.3  0.000000  12.1  357.0
# 704   130.030418  0.000000  0.000000  75.0   0.3  0.000000   0.0  357.0
# 829   149.000000  0.000000  0.003854  58.0   0.5  3.870877   7.5  357.0
# 860   142.000000  0.001471  0.004412  39.0   0.9  0.000000  12.0 -174.0
# 1096  123.000000  0.011189  0.001927  24.0   2.2  0.000000   1.7  357.0
# 1273  119.000000  0.007032  0.005626  21.0   1.6  0.000000   9.4 -174.0
# 1320  128.000000  0.006519  0.005215  21.0   2.4  0.000000   1.9 -174.0
#
#       Tendency       NSP
# 54         1.0  3.004535
# 64         1.0  1.000000
# 120        0.0  0.997921
# 389        0.0  1.000000
# 704       -1.0  3.000000
# ...

# %%
df['Width'] = winsorized_data

# %%
plt.boxplot(df['Width'])
plt.show()

# %%
# For Tendency column

# %%
plt.hist(df['Tendency'])
plt.show()

# %%
df['Tendency'].skew()
# Out:
# -0.49660151960673626

# %%
# plotting boxplot
box9 = plt.boxplot(df['Tendency'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box9['fliers']]
df[df['Tendency'].isin(outlier[0])]
# Out:
#          LB        AC        FM        UC        DL            DS   DP  \
# 449   135.0  0.001233  0.002466  0.000000  0.000000  0.000000e+00  0.0
# 692   133.0  0.007740  0.442724  0.004644  0.004644  0.000000e+00  0.0
# 952   136.0  0.009506  0.000000  0.005703  0.002852  0.000000e+00  0.0
# 1039  125.0  0.000000  0.000000  0.005217  0.000000  0.000000e+00  0.0
# 1098  122.0  0.000000 -0.000064  0.002516  0.000067  0.000000e+00  0.0
# 1318  125.0  0.002062  0.014433  0.006186  0.008247  0.000000e+00  0.0
# 1392  142.0  0.000000  0.000000  0.007463  0.000000  0.000000e+00  0.0
# 1595  134.0  0.000000  0.000000  0.005181  0.007772  0.000000e+00  0.0
# 1856  138.0  0.013713  0.000000  0.004219  0.000000  0.000000e+00  0.0
# 2088  133.0  0.000000  0.001236  0.006180  0.000000 -8.720000e-07  0.0
#
#            ASTV  MSTV  ALTV       MLTV       Width  Tendency  NSP
# 449   58.000000   0.6  15.0   8.000000   95.000000 -3.000000  1.0
# ...

# %%
# Winsoring the outlier
winsorized_data = winsorize(df['Tendency'], limits=[0.07, 0.05])

# %%
df['Tendency'] = winsorized_data
plt.boxplot(df['Tendency'])
plt.show()

# %%
plt.hist(df['NSP'])
plt.show()

# %%
df['NSP'].skew()
# Out:
# 1.779813564957202

# %%
# plotting boxplot
box10 = plt.boxplot(df['NSP'])
plt.show()

# %%
outlier = [item.get_ydata() for item in box10['fliers']]
df[df['NSP'].isin(outlier[0])]
# Out:
#          LB        AC        FM        UC        DL            DS        DP  \
# 0     120.0  0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000
# 5     134.0  0.001116  0.000000  0.010493  0.009444  0.000000e+00  0.002099
# 6     134.0  0.001403  0.000000  0.012623  0.008415  0.000000e+00  0.002805
# 7     122.0  0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000
# 8     122.0  0.038567  0.000000  0.001517  0.000000  0.000000e+00  0.000000
# ...     ...       ...       ...       ...       ...           ...       ...
# 2112  136.0  0.000000  0.004823  0.006431  0.008039  9.488398e-07  0.001608
# 2121  140.0  0.000000  0.961268  0.007426  0.000000  0.000000e+00  0.000000
# 2122  140.0  0.000775  0.000000  0.006979  0.000000  0.000000e+00  0.000000
# 2123  140.0  0.000980  0.000000  0.006863  0.000000  0.000000e+00  0.000000
# 2124  140.0  0.000679  0.000000  0.006110  0.000000  0.000000e+00  0.000000
#
# ...

# %% [markdown]
# Since there are more outliers we will drop the column

# %%
df.drop(columns='NSP', inplace=True)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency
# 0      0.5  43.000000   2.4   64.0  0.999926
# ...

# %% [markdown]
# ## Visualization

# %%
# Pairplot

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
